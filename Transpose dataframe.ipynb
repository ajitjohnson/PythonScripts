# %% [markdown]
# ## Function to transpose and save dataframe

# %%
import numpy as np
import pandas as pd
import os

# %%
WD = 'L:/Extended M drive/ImSIg/Single cell validation/melanoama'
os.chdir(WD)

# %%
data = np.transpose(pd.read_csv('melanoma_expression.csv', index_col=0))

# %%
data.head(5)
# Out:
# GENE                         C9orf152   RPS11   ELMO2  CREB3L1  PNMA1  \
# Cy72_CD45_H02_S758_comb           0.0  9.2172  0.0000      0.0    0.0
# CY58_1_CD45_B02_S974_comb         0.0  8.3745  0.0000      0.0    0.0
# Cy71_CD45_D08_S524_comb           0.0  9.3130  2.1263      0.0    0.0
# Cy81_FNA_CD45_B01_S301_comb       0.0  7.8876  0.0000      0.0    0.0
# Cy80_II_CD45_B07_S883_comb        0.0  8.3291  0.0000      0.0    0.0
#
# GENE                            MMP2  TMEM216  TRAF3IP2-AS1  LRRC37A5P  \
# Cy72_CD45_H02_S758_comb      0.00000   0.0000       2.85140        0.0
# CY58_1_CD45_B02_S974_comb    0.00000   0.0000       2.09830        0.0
# Cy71_CD45_D08_S524_comb      0.73812   0.0000       0.61730        0.0
# Cy81_FNA_CD45_B01_S301_comb  0.00000   0.0000       0.96495        0.0
# Cy80_II_CD45_B07_S883_comb   0.00000   3.7949       1.47350        0.0
#
# GENE                         LOC653712  ...     GPLD1  SNORD115-39   RAB8A  \
# ...

# %%
data.to_csv('mel-transposed.csv')
